# %%
import os
import pandas as pd
import numpy as np

# %%
K = {}
K['09'] = K09;K['08'] = K08;K['07'] = K07;K['06'] = K06;
for j in range (38):
    for i in ['9','8','7','6']:
        # print(len(K['0'+i].columns))
        print(K['0'+i].columns[j])
    print('')
# print(K08.columns)
# print(K07.columns)
# print(K06.columns)
# Out:
# K5
# K5
# K5
# K5
#
# H4K20me3
# H4K20me3
# H4K20me3
# H4K20me3
#
# panKeratin
# panKeratin
# panKeratin
# panKeratin
#
# ER
# ER
# ER
# ER
#
# CD49f
# CD49f
# CD49f
# CD49f
#
# CD24
# CD24
# CD24
# CD24
#
# GATA3
# GATA3
# GATA3
# GATA3
#
# H3K27me33
# H3K27me33
# H3K27me33
# H3K27me33
#
# H3K9me3
# H3K9me3
# H3K9me3
# H3K9me3
#
# H3K9me2
# H3K9me2
# H3K9me2
# H3K9me2
#
# H2Aub
# H2Aub
# H2Aub
# H2Aub
#
# H3.3
# H3.3
# H3.3
# H3.3
#
# H3K64ac
# H3K64ac
# H3K64ac
# H3K64ac
#
# BMI-1
# BMI-1
# BMI-1
# BMI-1
#
# Ecad
# Ecad
# Ecad
# Ecad
#
# H3K27ac
# H3K27ac
# H3K27ac
# H3K27ac
#
# H3K36me33
# H3K36me33
# H3K36me33
# H3K36me33
#
# H3
# H3
# H3
# H3
#
# DNA2
# DNA2
# DNA2
# DNA2
#
# H3S28p
# H3S28p
# H3S28p
# H3S28p
#
# H3K27me2
# H3K27me2
# H3K27me2
# H3K27me2
#
# Ncad
# Ncad
# Ncad
# Ncad
#
# EZH2
# EZH2
# EZH2
# EZH2
#
# H3K4me33
# H3K4me33
# H3K4me33
# H3K4me33
#
# aSMA
# aSMA
# aSMA
# aSMA
#
# H3K4me1
# H3K4me1
# H3K4me1
# H3K4me1
#
# EpCam
# EpCam
# EpCam
# EpCam
#
# gH2AX
# ...
